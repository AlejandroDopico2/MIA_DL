# %% [markdown]
# # Exercise 3. Pretrained Models
#
# *   Alejandro Dopico Castro (alejandro.dopico2@udc.es).
# *   Ana Xiangning Pereira Ezquerro (ana.ezquerro@udc.es).

# %%
import sys, os, shutil
IN_COLAB = "google.colab" in sys.modules
if IN_COLAB:
    from google.colab import drive
    drive.mount("/content/gdrive", force_remount=True)
os.chdir('/content/gdrive/My Drive/dl-labs/')
# if os.path.exists('animals/'):
    # shutil.rmtree('animals/')
# !unzip archive.zip -d .
# Out:
# Mounted at /content/gdrive

# %%
from keras.layers import Conv2D, Input, Rescaling, MaxPooling2D, Flatten, Dense
from keras.models import Sequential
from keras.optimizers import Adam
from layers import Inception
from classifier import AnimalImageClassifier
from utils import load_data
IMG_SIZE = 200
BATCH_SIZE = 64

# load data
train, dev, test = load_data('animals/', IMG_SIZE, BATCH_SIZE)
# Out:
# Found 1782 files belonging to 5 classes.
# Using 1515 files for training.
# Using 267 files for validation.
# Found 609 files belonging to 5 classes.

# %% [markdown]
# ## Inception-based Model

# %%
model = Sequential([
    Input(shape=(IMG_SIZE, IMG_SIZE, 3)),
    Rescaling(1./255),
    Inception((32, 32, 32, 32)),
    Conv2D(64, 5), Conv2D(64, 5), MaxPooling2D(3),
    Conv2D(128, 5), Conv2D(128, 5), MaxPooling2D(3),
    Conv2D(128, 5), Conv2D(128, 5), MaxPooling2D(3),
    Flatten(), Dense(5, activation='softmax')
])
classifier = AnimalImageClassifier('inception-based', model, IMG_SIZE)
optimizer = Adam(learning_rate=1e-4)
classifier.train(train, dev, optimizer, 'results/', batch_size=BATCH_SIZE)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 200, 200, 3)       0
#
#  inception (Inception)       (None, 200, 200, 128)     28256
#
#  conv2d_7 (Conv2D)           (None, 196, 196, 64)      204864
#
#  conv2d_8 (Conv2D)           (None, 192, 192, 64)      102464
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 64)        0
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 60, 60, 128)       204928
#
#  conv2d_10 (Conv2D)          (None, 56, 56, 128)       409728
#
#  max_pooling2d_2 (MaxPoolin  (None, 18, 18, 128)       0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 14, 14, 128)       409728
#
#  conv2d_12 (Conv2D)          (None, 10, 10, 128)       409728
#
#  max_pooling2d_3 (MaxPoolin  (None, 3, 3, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 5)                 5765
#
# =================================================================
# Total params: 1775461 (6.77 MB)
# Trainable params: 1775461 (6.77 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/20
# 24/24 [==============================] - 782s 21s/step - loss: 0.8973 - sparse_categorical_accuracy: 0.7380 - val_loss: 0.6826 - val_sparse_categorical_accuracy: 0.8052 - lr: 1.0000e-04
# Epoch 2/20
# 24/24 [==============================] - 25s 937ms/step - loss: 0.7114 - sparse_categorical_accuracy: 0.7736 - val_loss: 0.5721 - val_sparse_categorical_accuracy: 0.8052 - lr: 1.0000e-04
# Epoch 3/20
# 24/24 [==============================] - 26s 973ms/step - loss: 0.6041 - sparse_categorical_accuracy: 0.7855 - val_loss: 0.4499 - val_sparse_categorical_accuracy: 0.8352 - lr: 1.0000e-04
# Epoch 4/20
# 24/24 [==============================] - 26s 953ms/step - loss: 0.5400 - sparse_categorical_accuracy: 0.8205 - val_loss: 0.4497 - val_sparse_categorical_accuracy: 0.8577 - lr: 1.0000e-04
# Epoch 5/20
# 24/24 [==============================] - 26s 958ms/step - loss: 0.4494 - sparse_categorical_accuracy: 0.8495 - val_loss: 0.3851 - val_sparse_categorical_accuracy: 0.8951 - lr: 1.0000e-04
# Epoch 6/20
# 24/24 [==============================] - 27s 997ms/step - loss: 0.3477 - sparse_categorical_accuracy: 0.8858 - val_loss: 0.3749 - val_sparse_categorical_accuracy: 0.8989 - lr: 1.0000e-04
# Epoch 7/20
# 24/24 [==============================] - 26s 982ms/step - loss: 0.2890 - sparse_categorical_accuracy: 0.9043 - val_loss: 0.3334 - val_sparse_categorical_accuracy: 0.9026 - lr: 1.0000e-04
# Epoch 8/20
# 24/24 [==============================] - 23s 840ms/step - loss: 0.2007 - sparse_categorical_accuracy: 0.9307 - val_loss: 0.3736 - val_sparse_categorical_accuracy: 0.9026 - lr: 1.0000e-04
# Epoch 9/20
# 24/24 [==============================] - 24s 892ms/step - loss: 0.1266 - sparse_categorical_accuracy: 0.9525 - val_loss: 0.4419 - val_sparse_categorical_accuracy: 0.9139 - lr: 1.0000e-04
# Epoch 10/20
# 24/24 [==============================] - 23s 848ms/step - loss: 0.0957 - sparse_categorical_accuracy: 0.9663 - val_loss: 0.3637 - val_sparse_categorical_accuracy: 0.8876 - lr: 1.0000e-04
# Epoch 11/20
# 24/24 [==============================] - 23s 845ms/step - loss: 0.0479 - sparse_categorical_accuracy: 0.9855 - val_loss: 0.4646 - val_sparse_categorical_accuracy: 0.8951 - lr: 1.0000e-04
# Epoch 12/20
# 24/24 [==============================] - 23s 812ms/step - loss: 0.0337 - sparse_categorical_accuracy: 0.9908 - val_loss: 0.5650 - val_sparse_categorical_accuracy: 0.9026 - lr: 1.0000e-04
# Epoch 13/20
# 24/24 [==============================] - 22s 819ms/step - loss: 0.0132 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.4997 - val_sparse_categorical_accuracy: 0.9101 - lr: 2.0000e-05
# Epoch 14/20
# 24/24 [==============================] - 24s 868ms/step - loss: 0.0063 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5063 - val_sparse_categorical_accuracy: 0.9251 - lr: 2.0000e-05
# Epoch 15/20
# 24/24 [==============================] - 23s 850ms/step - loss: 0.0047 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5124 - val_sparse_categorical_accuracy: 0.9213 - lr: 2.0000e-05
# Epoch 16/20
# 24/24 [==============================] - 24s 890ms/step - loss: 0.0039 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5178 - val_sparse_categorical_accuracy: 0.9213 - lr: 2.0000e-05
# Epoch 17/20
# 24/24 [==============================] - 23s 832ms/step - loss: 0.0034 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5263 - val_sparse_categorical_accuracy: 0.9213 - lr: 2.0000e-05
